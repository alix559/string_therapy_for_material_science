# %%
#| default_exp main

# %%
#| export 
from string_therapy import ensure_schema, seed_router_db, serve_controller

ensure_schema()
seed_router_db('routes/router_graph.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 #| export
#       2 from string_therapy import ensure_schema, seed_router_db, serve_controller
#       3
# ----> 4 ensure_schema()
#       5 seed_router_db('routes/router_graph.json')
#
# File ~/python_projects/string_therapy_for_material_science/.pixi/envs/default/lib/python3.13/site-packages/string_therapy/schema.py:55, in ensure_schema(dsn)
#      53 url = dsn or default_database_url()
#      54 if not url:
# ---> 55     raise ValueError('Set ROUTER_DATABASE_URL or pass dsn= to ensure_schema')
#      57 with psycopg.connect(url) as conn:
#      58     with conn.transaction():
#
# ValueError: Set ROUTER_DATABASE_URL or pass dsn= to ensure_schema
